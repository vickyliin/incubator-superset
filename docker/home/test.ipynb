# %%
from sqlalchemy import create_engine
import pandas as pd

# %%
engine = create_engine('mysql://superset:superset@mysql:3306/superset')

# %%
df = pd.read_csv('./gc_activities_kr.csv', index_col='ACTIVITY_ID')
for col in ['UPDATE_DATE', 'CREATION_DATE', 'START_TIME_GMT']:
    df[col] = pd.to_datetime(df[col])
df.head()
# Out:
#             Country  ACTIVITY_TYPE_PK  ACTIVITY_TYPE  PARENT_ACTIVITY_TYPE_PK  \
# ACTIVITY_ID
# 2030899128       KR                27   lap_swimming                       26
# 2030721115       KR                 6  trail_running                        1
# 2026731326       KR                 9        walking                       17
# 2031141199       KR                 1        running                       17
# 2031143139       KR                 2        cycling                       17
#
#             PARENT_ACTIVITY_TYPE EVENT_TYPE_KEY  UPDATE_DATE_MS  \
# ACTIVITY_ID
# 2030899128              swimming  uncategorized   1506862911000
# 2030721115               running  uncategorized   1506859161000
# 2026731326                   all  uncategorized   1506816364000
# 2031141199                   all  uncategorized   1506866054000
# 2031143139                   all  uncategorized   1506866250000
#
#              CREATION_DATE_MS  START_TIME_GMT_MS    DURATION     ...      \
# ...

# %%
df[['START_TIME_GMT', 'ACTIVITY_TYPE', 'START_LONGITUDE', 'START_LATITUDE']] \
        .to_sql('gc_activities_kr', engine, chunksize=1000, if_exists='replace')
